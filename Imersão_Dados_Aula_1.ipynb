# %% [markdown]
# <a href="https://colab.research.google.com/github/ericlesn/ImersaoDados/blob/main/Imers%C3%A3o_Dados_Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
dados["SG_UF_RESIDENCIA"].count()
# Out:
# 127380

# %%
len(dados["NO_MUNICIPIO_RESIDENCIA"].unique())
# Out:
# 4889

# %%
dados["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados["NO_MUNICIPIO_RESIDENCIA"].value_counts()
# Out:
# São Paulo             5718
# Rio de Janeiro        3453
# Brasília              2408
# Fortaleza             2397
# Salvador              2215
#                       ...
# Santana dos Montes       1
# Campo Belo do Sul        1
# Segredo                  1
# Coronel Pacheco          1
# Itaguatins               1
# Name: NO_MUNICIPIO_RESIDENCIA, Length: 4889, dtype: int64

# %%
dados["NU_IDADE"].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados["NU_NOTA_REDACAO"].value_counts()
# Out:
# 600.0     6938
# 560.0     6841
# 580.0     6470
# 620.0     5074
# 640.0     4985
# 540.0     4942
# 520.0     4921
# 480.0     4140
# 0.0       3505
# 680.0     3462
# 500.0     3401
# 660.0     3314
# 460.0     2780
# 440.0     2776
# 720.0     2593
# 700.0     2362
# 760.0     2180
# 740.0     1920
# 800.0     1812
# 400.0     1678
# 320.0     1673
# 360.0     1622
# 420.0     1597
# 840.0     1560
# 780.0     1505
# 880.0     1425
# 920.0     1274
# 820.0     1206
# 340.0     1197
# 860.0     1134
# 300.0     1123
# 900.0     1119
# 280.0     1102
# 380.0     1062
# 940.0      994
# 960.0      677
# 260.0      614
# 240.0      477
# 980.0      224
# 220.0      190
# 200.0       94
# 160.0       28
# 180.0       27
# 140.0       11
# 120.0        4
# 40.0         2
# 1000.0       2
# 60.0         2
# 100.0        2
# 80.0         2
# Name: NU_NOTA_REDACAO, dtype: int64

# %%
dados["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados["NU_IDADE"].hist()

# %%
dados["NU_IDADE"].hist(bins = 20)

# %%
dados["NU_IDADE"].hist(bins = 20, figsize = (10, 8))

# %%
dados.query("IN_TREINEIRO == 1")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# 12      190001005076    2019                  1506138  ...    A     A    B
# 14      190001005081    2019                  1506807  ...    A     A    B
# 16      190001005202    2019                  1502301  ...    A     A    A
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127328  190006117441    2019                  3126752  ...    A     A    B
# 127340  190006117776    2019                  4305108  ...    A     C    B
# 127349  190006118483    2019                  2511301  ...    A     A    A
# 127350  190006118551    2019                  2611606  ...    B     B    B
# 127352  190006118561    2019                  2600807  ...    A     A    B
#
# [15401 rows x 136 columns]

# %%
dados.query("IN_TREINEIRO == 1")["IN_TREINEIRO"]
# Out:
# 0         1
# 4         1
# 12        1
# 14        1
# 16        1
#          ..
# 127328    1
# 127340    1
# 127349    1
# 127350    1
# 127352    1
# Name: IN_TREINEIRO, Length: 15401, dtype: int64

# %%
dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts()
# Out:
# 16    7142
# 17    4901
# 15    1927
# 18     858
# 19     228
# 20      83
# 14      64
# 21      44
# 22      30
# 23      21
# 24      13
# 26      13
# 29      10
# 27       9
# 25       8
# 28       6
# 38       4
# 40       4
# 31       4
# 30       4
# 42       4
# 34       3
# 36       2
# 39       2
# 32       2
# 46       2
# 44       2
# 35       2
# 45       1
# 41       1
# 33       1
# 62       1
# 48       1
# 51       1
# 37       1
# 47       1
# 55       1
# Name: NU_IDADE, dtype: int64

# %%
dados["NU_NOTA_REDACAO"].hist(bins = 20, figsize =(10,8))

# %%
dados["NU_NOTA_LC"].hist(bins = 20, figsize =(10,8))

# %%
dados["NU_NOTA_REDACAO"].mean() #media da redação
# Out:
# 571.5700253970197

# %%
dados["NU_NOTA_REDACAO"].std() #desvio padrão
# Out:
# 188.07645455749753

# %%
provas =["NU_NOTA_REDACAO", "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_MT"]

dados[provas].describe()
#descreve estatisticamente o que foi selecionado
# Out:
#        NU_NOTA_REDACAO    NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_LC    NU_NOTA_MT
# count     98043.000000  92758.000000  98043.000000  98043.000000  92758.000000
# mean        571.570025    477.964015    507.365912    520.463928    523.555206
# std         188.076455     76.296099     82.972839     64.556578    109.416939
# min           0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         480.000000    418.000000    447.900000    483.700000    435.300000
# 50%         580.000000    470.200000    510.900000    526.100000    501.600000
# 75%         680.000000    533.300000    567.100000    565.100000    598.200000
# max        1000.000000    797.300000    809.400000    801.700000    985.000000

# %%
dados["NU_NOTA_LC"].quantile(0.9)
# Out:
# 596.3

# %%
dados["NU_NOTA_LC"].plot.box(grid = True,figsize =(8,6))

# %%
dados[provas].boxplot(grid = True,figsize =(8,6))
